# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaRoy-c566/LGMVIP_DS_Internship/blob/main/Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image to Pencil Sketch with Python

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# `Error: cv2.imshow(img) is crashing the kernel`
#
# Since we are using Google Colab, we can execute :
#
# ```
# import cv2_imshow
# cv2_imshow(img)
# ```

# %%
image = cv2.imread("cat.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7FB18ACC0D50>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB18ACC0990>

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB18ACDD550>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB18ACD3810>
